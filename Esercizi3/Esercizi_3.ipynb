# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>

# %% [markdown]
# ## Brandon Tatani - 931529

# %% [markdown]
# ## <span style="color:blue">  Numerical exercises 3</span>

# %% [markdown]
# ### Exercise 03.1
# By using the following parameters:
# - asset price at $t=0$: $S(0)=100$
# - delivery time: $T=1$
# - strike price: $K=100$
# - risk-free interest rate: $r=0.1$
# - volatility: $\sigma=0.25$
#
# compute at time $t=0$ **via Monte Carlo** the European call-option price, $C[S(0),0]$, and put-option price, $P[S(0),0]$:

# %% [markdown]
# 1. <span style="color:red"> By sampling **directly** the final asset price $S(T)$</span> for a $GBM(r,\sigma^2)$
# 2. <span style="color:red"> By sampling the discretized $GBM(r,\sigma^2)$ path of the asset price</span>
# dividing $[0,T]$ in $10^2$ time intervals: $S(0)$, $S(t_1)$, $S(t_2)$, ... up to $S(t_{100}=T=1)$

# %% [markdown]
# <span style="color:red">Make four pictures for the estimation of the European call-option prices, $C[S(0),0]$ (direct and discretized), and put-option prices, $P[S(0),0]$ (direct and discretized), with their uncertainties </span> with a large number of asset prices at time $t=T$, say $M\ge 10^4$, as a function of the number of blocks, $N$</font>. <span style="color:blue"> As usual, in computing statistical uncertainties, use data blocking.</span>

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#variabili
N = 100
x = np.arange(N);

#loading data
data = pd.read_csv('output3_1.csv')
y_call = data['Call']
err_call = data['Err_Call']
y_put = data['Put']
err_put = data['Err_Put']
y_true = np.ones(N)*14.975790778311286
true_put = np.ones(N)*5.4595325819072364

#plotting data
plt.figure(figsize=(20, 20))
plt.subplots_adjust()

plt.subplot(211)
plt.errorbar(x, y_call, yerr=err_call)
plt.plot(x, y_true, 'r-')
plt.title('Call-Option Price with direct sampling')
plt.xlabel('#steps')
plt.ylabel('Option Price')

plt.subplot(212)
plt.errorbar(x, y_put, yerr=err_put)
plt.plot(x, true_put, 'r-')
plt.title('Put-Option Price with one estimation?')
plt.xlabel('#blocks')
plt.ylabel('Option Price')
plt.show()

# %% [markdown]
# #### Discretized Sampling

# %%
data = pd.read_csv('output3_2.csv')
y_call = data['Call']
err_call = data['Err_Call']
y_put = data['Put']
err_put = data['Err_Put']

#plotting data
plt.figure(figsize=(20, 20))
plt.subplots_adjust()

plt.subplot(211)
plt.errorbar(x, y_call, yerr=err_call)
plt.plot(x, y_true, 'r-')
plt.title('Call-Option Price with discretized sampling')
plt.xlabel('#block')
plt.ylabel('Option Price')

plt.subplot(212)
plt.errorbar(x, y_put, yerr=err_put)
plt.plot(x, true_put, 'r-')
plt.title('Put-Option Price with discretized sampling')
plt.xlabel('#block')
plt.ylabel('Option Price')

plt.show()
